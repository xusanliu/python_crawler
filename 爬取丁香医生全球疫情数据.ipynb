# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import json

# %%
url='http://ncov.dxy.cn/ncovh5/view/pneumonia'
html=requests.get(url).content.decode('utf-8')
data=re.findall('getListByCountryTypeService2true = (.*?)}catch',html)[0]
data=json.loads(data)
data
# Out:
# [{'id': 2551902,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '8',
#   'provinceName': '美国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 555949,
#   'confirmedCount': 639628,
#   'confirmedCountRank': 1,
#   'suspectedCount': 0,
#   'curedCount': 52699,
#   'deadCount': 30980,
#   'deadCountRank': 1,
#   'deadRate': '4.84',
#   'deadRateRank': 36,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971002,
#   'countryShortCode': 'USA',
#   'countryFullName': 'United States of America',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/553/3402160512808052518-135.json',
#   'incrVo': {'currentConfirmedIncr': 21,
#    'confirmedIncr': 3278,
#    'curedIncr': 603,
#    'deadIncr': 2654},
#   'showRank': True},
#  {'id': 2551914,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '意大利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 105418,
#   'confirmedCount': 165155,
#   'confirmedCountRank': 3,
#   'suspectedCount': 0,
#   'curedCount': 38092,
#   'deadCount': 21645,
#   'deadCountRank': 2,
#   'deadRate': '13.10',
#   'deadRateRank': 4,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965008,
#   'countryShortCode': 'ITA',
#   'countryFullName': 'Italy',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/993/3402160517102843054-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551916,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '西班牙',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 88201,
#   'confirmedCount': 177633,
#   'confirmedCountRank': 2,
#   'suspectedCount': 0,
#   'curedCount': 70853,
#   'deadCount': 18579,
#   'deadCountRank': 3,
#   'deadRate': '10.45',
#   'deadRateRank': 7,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965015,
#   'countryShortCode': 'ESP',
#   'countryFullName': 'Spain',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/812/3402160512807875660-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552008,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '英国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 85264,
#   'confirmedCount': 98476,
#   'confirmedCountRank': 6,
#   'suspectedCount': 0,
#   'curedCount': 344,
#   'deadCount': 12868,
#   'deadCountRank': 5,
#   'deadRate': '13.06',
#   'deadRateRank': 5,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961007,
#   'countryShortCode': 'GBR',
#   'countryFullName': 'The United Kingdom',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/364/3402160538577680395-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552292,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '土耳其',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 62200,
#   'confirmedCount': 69392,
#   'confirmedCountRank': 9,
#   'suspectedCount': 0,
#   'curedCount': 5674,
#   'deadCount': 1518,
#   'deadCountRank': 12,
#   'deadRate': '2.18',
#   'deadRateRank': 78,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955018,
#   'countryShortCode': 'TUR',
#   'countryFullName': 'Turkey',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/952/3402160538577680436-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551899,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '5',
#   'provinceName': '法国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 58039,
#   'confirmedCount': 106206,
#   'confirmedCountRank': 5,
#   'suspectedCount': 0,
#   'curedCount': 31000,
#   'deadCount': 17167,
#   'deadCountRank': 4,
#   'deadRate': '16.16',
#   'deadRateRank': 1,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961002,
#   'countryShortCode': 'FRA',
#   'countryFullName': 'France',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/929/3402160538577857318-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551908,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '德国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 49881,
#   'confirmedCount': 130450,
#   'confirmedCountRank': 4,
#   'suspectedCount': 0,
#   'curedCount': 77000,
#   'deadCount': 3569,
#   'deadCountRank': 8,
#   'deadRate': '2.73',
#   'deadRateRank': 67,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963003,
#   'countryShortCode': 'DEU',
#   'countryFullName': 'Germany',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/631/3402160538577680475-135.json',
#   'incrVo': {'currentConfirmedIncr': -4337,
#    'confirmedIncr': 378,
#    'curedIncr': 4400,
#    'deadIncr': 315},
#   'showRank': True},
#  {'id': 2551915,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '俄罗斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 25402,
#   'confirmedCount': 27938,
#   'confirmedCountRank': 14,
#   'suspectedCount': 0,
#   'curedCount': 2304,
#   'deadCount': 232,
#   'deadCountRank': 28,
#   'deadRate': '0.83',
#   'deadRateRank': 107,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964006,
#   'countryShortCode': 'RUS',
#   'countryFullName': 'Russian Federation',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/629/3402160517102843039-135.json',
#   'incrVo': {'currentConfirmedIncr': 3096,
#    'confirmedIncr': 3448,
#    'curedIncr': 318,
#    'deadIncr': 34},
#   'showRank': True},
#  {'id': 2551964,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '荷兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 24728,
#   'confirmedCount': 28153,
#   'confirmedCountRank': 13,
#   'suspectedCount': 0,
#   'curedCount': 291,
#   'deadCount': 3134,
#   'deadCountRank': 10,
#   'deadRate': '11.13',
#   'deadRateRank': 6,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961006,
#   'countryShortCode': 'NLD',
#   'countryFullName': 'Netherlands',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/850/3402160510660568773-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551906,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '加拿大',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 24601,
#   'confirmedCount': 28381,
#   'confirmedCountRank': 12,
#   'suspectedCount': 0,
#   'curedCount': 2770,
#   'deadCount': 1010,
#   'deadCountRank': 15,
#   'deadRate': '3.55',
#   'deadRateRank': 54,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971001,
#   'countryShortCode': 'CAN',
#   'countryFullName': 'Canada',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/505/3402160534282712951-135.json',
#   'incrVo': {'currentConfirmedIncr': 2,
#    'confirmedIncr': 2,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551929,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '比利时',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 22026,
#   'confirmedCount': 33573,
#   'confirmedCountRank': 10,
#   'suspectedCount': 0,
#   'curedCount': 7107,
#   'deadCount': 4440,
#   'deadCountRank': 7,
#   'deadRate': '13.22',
#   'deadRateRank': 3,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961001,
#   'countryShortCode': 'BEL',
#   'countryFullName': 'Belgium',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/838/3402160514955359353-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551944,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '伊朗',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 21679,
#   'confirmedCount': 76389,
#   'confirmedCountRank': 8,
#   'suspectedCount': 0,
#   'curedCount': 49933,
#   'deadCount': 4777,
#   'deadCountRank': 6,
#   'deadRate': '6.25',
#   'deadRateRank': 21,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955007,
#   'countryShortCode': 'IRN',
#   'countryFullName': 'Iran (Islamic Republic of)',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/596/3402160510660568739-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552048,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '葡萄牙',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 17109,
#   'confirmedCount': 18091,
#   'confirmedCountRank': 16,
#   'suspectedCount': 0,
#   'curedCount': 383,
#   'deadCount': 599,
#   'deadCountRank': 16,
#   'deadRate': '3.31',
#   'deadRateRank': 57,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965010,
#   'countryShortCode': 'PRT',
#   'countryFullName': 'Portugal',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/256/3402160527840261777-135.json',
#   'incrVo': {'currentConfirmedIncr': -4,
#    'confirmedIncr': 0,
#    'curedIncr': 4,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551958,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '巴西',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 13126,
#   'confirmedCount': 28912,
#   'confirmedCountRank': 11,
#   'suspectedCount': 0,
#   'curedCount': 14026,
#   'deadCount': 1760,
#   'deadCountRank': 11,
#   'deadRate': '6.08',
#   'deadRateRank': 22,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973003,
#   'countryShortCode': 'BRA',
#   'countryFullName': 'Brazil',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/559/3402160538577857305-135.json',
#   'incrVo': {'currentConfirmedIncr': 568,
#    'confirmedIncr': 592,
#    'curedIncr': 0,
#    'deadIncr': 24},
#   'showRank': True},
#  {'id': 2552010,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '爱尔兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 12041,
#   'confirmedCount': 12547,
#   'confirmedCountRank': 19,
#   'suspectedCount': 0,
#   'curedCount': 62,
#   'deadCount': 444,
#   'deadCountRank': 19,
#   'deadRate': '3.53',
#   'deadRateRank': 55,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961003,
#   'countryShortCode': 'IRL',
#   'countryFullName': 'Ireland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/153/3402160510660568721-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551917,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '瑞典',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 10791,
#   'confirmedCount': 12031,
#   'confirmedCountRank': 21,
#   'suspectedCount': 0,
#   'curedCount': 17,
#   'deadCount': 1223,
#   'deadCountRank': 14,
#   'deadRate': '10.16',
#   'deadRateRank': 8,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 962005,
#   'countryShortCode': 'SWE',
#   'countryFullName': 'Sweden',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/516/3402160512807875646-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551913,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '印度',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 10477,
#   'confirmedCount': 12380,
#   'confirmedCountRank': 20,
#   'suspectedCount': 0,
#   'curedCount': 1489,
#   'deadCount': 414,
#   'deadCountRank': 20,
#   'deadRate': '3.34',
#   'deadRateRank': 56,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953003,
#   'countryShortCode': 'IND',
#   'countryFullName': 'India',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/045/3402160534282889835-135.json',
#   'incrVo': {'currentConfirmedIncr': 280,
#    'confirmedIncr': 447,
#    'curedIncr': 145,
#    'deadIncr': 22},
#   'showRank': True},
#  {'id': 2551945,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '以色列',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 9827,
#   'confirmedCount': 12591,
#   'confirmedCountRank': 18,
#   'suspectedCount': 0,
#   'curedCount': 2624,
#   'deadCount': 140,
#   'deadCountRank': 37,
#   'deadRate': '1.11',
#   'deadRateRank': 99,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955009,
#   'countryShortCode': 'ISR',
#   'countryFullName': 'Israel',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/982/3402160514955536220-135.json',
#   'incrVo': {'currentConfirmedIncr': 19,
#    'confirmedIncr': 90,
#    'curedIncr': 61,
#    'deadIncr': 10},
#   'showRank': True},
#  {'id': 2551953,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '瑞士',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 9626,
#   'confirmedCount': 26264,
#   'confirmedCountRank': 15,
#   'suspectedCount': 0,
#   'curedCount': 15400,
#   'deadCount': 1238,
#   'deadCountRank': 13,
#   'deadRate': '4.71',
#   'deadRateRank': 37,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963008,
#   'countryShortCode': 'CHE',
#   'countryFullName': 'Switzerland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/786/3402160525692954837-135.json',
#   'incrVo': {'currentConfirmedIncr': -827,
#    'confirmedIncr': -72,
#    'curedIncr': 700,
#    'deadIncr': 55},
#   'showRank': True},
#  {'id': 2551900,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '6',
#   'provinceName': '日本',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 8140,
#   'confirmedCount': 8723,
#   'confirmedCountRank': 23,
#   'suspectedCount': 0,
#   'curedCount': 404,
#   'deadCount': 179,
#   'deadCountRank': 33,
#   'deadRate': '2.05',
#   'deadRateRank': 82,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 951002,
#   'countryShortCode': 'JPN',
#   'countryFullName': 'Japan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/220/3402160536430373556-135.json',
#   'incrVo': {'currentConfirmedIncr': 225,
#    'confirmedIncr': 235,
#    'curedIncr': 0,
#    'deadIncr': 10},
#   'showRank': True},
#  {'id': 2552012,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '厄瓜多尔',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6733,
#   'confirmedCount': 7603,
#   'confirmedCountRank': 25,
#   'suspectedCount': 0,
#   'curedCount': 501,
#   'deadCount': 369,
#   'deadCountRank': 23,
#   'deadRate': '4.85',
#   'deadRateRank': 34,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973006,
#   'countryShortCode': 'ECU',
#   'countryFullName': 'Ecuador',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/922/3402160517103019900-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551962,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '挪威',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6648,
#   'confirmedCount': 6798,
#   'confirmedCountRank': 29,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 150,
#   'deadCountRank': 35,
#   'deadRate': '2.20',
#   'deadRateRank': 77,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 962004,
#   'countryShortCode': 'NOR',
#   'countryFullName': 'Norway',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/616/3402160534282889764-135.json',
#   'incrVo': {'currentConfirmedIncr': 58,
#    'confirmedIncr': 58,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552140,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '波兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6628,
#   'confirmedCount': 7582,
#   'confirmedCountRank': 26,
#   'suspectedCount': 0,
#   'curedCount': 668,
#   'deadCount': 286,
#   'deadCountRank': 27,
#   'deadRate': '3.77',
#   'deadRateRank': 52,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963006,
#   'countryShortCode': 'POL',
#   'countryFullName': 'Poland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/811/3402160506365424422-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551955,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '奥地利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6333,
#   'confirmedCount': 14350,
#   'confirmedCountRank': 17,
#   'suspectedCount': 0,
#   'curedCount': 7633,
#   'deadCount': 384,
#   'deadCountRank': 21,
#   'deadRate': '2.67',
#   'deadRateRank': 70,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963001,
#   'countryShortCode': 'AUT',
#   'countryFullName': 'Austria',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/012/3402160532135229192-135.json',
#   'incrVo': {'currentConfirmedIncr': 29,
#    'confirmedIncr': 29,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551905,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '澳大利亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6286,
#   'confirmedCount': 6468,
#   'confirmedCountRank': 31,
#   'suspectedCount': 0,
#   'curedCount': 119,
#   'deadCount': 63,
#   'deadCountRank': 52,
#   'deadRate': '0.97',
#   'deadRateRank': 103,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 990001,
#   'countryShortCode': 'AUS',
#   'countryFullName': 'Australia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/646/3402160532135406038-135.json',
#   'incrVo': {'currentConfirmedIncr': 50,
#    'confirmedIncr': 52,
#    'curedIncr': 0,
#    'deadIncr': 2},
#   'showRank': True},
#  {'id': 2552060,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '智利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5812,
#   'confirmedCount': 8273,
#   'confirmedCountRank': 24,
#   'suspectedCount': 0,
#   'curedCount': 2367,
#   'deadCount': 94,
#   'deadCountRank': 45,
#   'deadRate': '1.13',
#   'deadRateRank': 98,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973004,
#   'countryShortCode': 'CHL',
#   'countryFullName': 'Chile',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/808/3402160527840261646-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551959,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '罗马尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5627,
#   'confirmedCount': 7216,
#   'confirmedCountRank': 28,
#   'suspectedCount': 0,
#   'curedCount': 1217,
#   'deadCount': 372,
#   'deadCountRank': 22,
#   'deadRate': '5.15',
#   'deadRateRank': 27,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965011,
#   'countryShortCode': 'ROU',
#   'countryFullName': 'Romania',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/131/3402160534282712963-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552161,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '秘鲁',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5528,
#   'confirmedCount': 7519,
#   'confirmedCountRank': 27,
#   'suspectedCount': 0,
#   'curedCount': 1798,
#   'deadCount': 193,
#   'deadCountRank': 30,
#   'deadRate': '2.56',
#   'deadRateRank': 72,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973008,
#   'countryShortCode': 'PER',
#   'countryFullName': 'Peru',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/005/3402160540725341040-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551970,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '墨西哥',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5397,
#   'confirmedCount': 5847,
#   'confirmedCountRank': 35,
#   'suspectedCount': 0,
#   'curedCount': 1,
#   'deadCount': 449,
#   'deadCountRank': 18,
#   'deadRate': '7.67',
#   'deadRateRank': 15,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971003,
#   'countryShortCode': 'MEX',
#   'countryFullName': 'Mexico',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/566/3402160534282889843-135.json',
#   'incrVo': {'currentConfirmedIncr': 405,
#    'confirmedIncr': 448,
#    'curedIncr': 0,
#    'deadIncr': 43},
#   'showRank': True},
#  {'id': 2552015,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '捷克',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5231,
#   'confirmedCount': 6216,
#   'confirmedCountRank': 33,
#   'suspectedCount': 0,
#   'curedCount': 819,
#   'deadCount': 166,
#   'deadCountRank': 34,
#   'deadRate': '2.67',
#   'deadRateRank': 70,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963002,
#   'countryShortCode': 'CZE',
#   'countryFullName': 'Czechia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/497/3402160532135229255-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551918,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '菲律宾',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4863,
#   'confirmedCount': 5660,
#   'confirmedCountRank': 36,
#   'suspectedCount': 0,
#   'curedCount': 435,
#   'deadCount': 362,
#   'deadCountRank': 24,
#   'deadRate': '6.39',
#   'deadRateRank': 18,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952008,
#   'countryShortCode': 'PHL',
#   'countryFullName': 'Philippines',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/180/3402160512807875628-135.json',
#   'incrVo': {'currentConfirmedIncr': 112,
#    'confirmedIncr': 207,
#    'curedIncr': 82,
#    'deadIncr': 13},
#   'showRank': True},
#  {'id': 2552020,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '沙特阿拉伯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4852,
#   'confirmedCount': 5862,
#   'confirmedCountRank': 34,
#   'suspectedCount': 0,
#   'curedCount': 931,
#   'deadCount': 79,
#   'deadCountRank': 48,
#   'deadRate': '1.34',
#   'deadRateRank': 96,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955016,
#   'countryShortCode': 'SAU',
#   'countryFullName': 'Saudi Arabia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/830/3402160536430373532-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551957,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '巴基斯坦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4826,
#   'confirmedCount': 6383,
#   'confirmedCountRank': 32,
#   'suspectedCount': 0,
#   'curedCount': 1446,
#   'deadCount': 111,
#   'deadCountRank': 42,
#   'deadRate': '1.73',
#   'deadRateRank': 88,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953006,
#   'countryShortCode': 'PAK',
#   'countryFullName': 'Pakistan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/432/3402160525692777910-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552159,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '塞尔维亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4647,
#   'confirmedCount': 4867,
#   'confirmedCountRank': 40,
#   'suspectedCount': 0,
#   'curedCount': 118,
#   'deadCount': 102,
#   'deadCountRank': 43,
#   'deadRate': '2.09',
#   'deadRateRank': 81,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965013,
#   'countryShortCode': 'SRB',
#   'countryFullName': 'Serbia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/316/3402160534282712994-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552017,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '印度尼西亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4472,
#   'confirmedCount': 5516,
#   'confirmedCountRank': 37,
#   'suspectedCount': 0,
#   'curedCount': 548,
#   'deadCount': 496,
#   'deadCountRank': 17,
#   'deadRate': '8.99',
#   'deadRateRank': 10,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952005,
#   'countryShortCode': 'IDN',
#   'countryFullName': 'Indonesia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/308/3402160527840438594-135.json',
#   'incrVo': {'currentConfirmedIncr': 231,
#    'confirmedIncr': 380,
#    'curedIncr': 122,
#    'deadIncr': 27},
#   'showRank': True},
#  {'id': 2551911,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '阿联酋',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4298,
#   'confirmedCount': 5365,
#   'confirmedCountRank': 38,
#   'suspectedCount': 0,
#   'curedCount': 1034,
#   'deadCount': 33,
#   'deadCountRank': 65,
#   'deadRate': '0.61',
#   'deadRateRank': 116,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955019,
#   'countryShortCode': 'ARE',
#   'countryFullName': 'United Arab Emirates',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/584/3402160508513084973-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552044,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '乌克兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3859,
#   'confirmedCount': 4161,
#   'confirmedCountRank': 41,
#   'suspectedCount': 0,
#   'curedCount': 186,
#   'deadCount': 116,
#   'deadCountRank': 40,
#   'deadRate': '2.78',
#   'deadRateRank': 63,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964007,
#   'countryShortCode': 'UKR',
#   'countryFullName': 'Ukraine',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/280/3402160525692954803-135.json',
#   'incrVo': {'currentConfirmedIncr': 346,
#    'confirmedIncr': 397,
#    'curedIncr': 43,
#    'deadIncr': 8},
#   'showRank': True},
#  {'id': 2551961,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '丹麦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3624,
#   'confirmedCount': 6681,
#   'confirmedCountRank': 30,
#   'suspectedCount': 0,
#   'curedCount': 2748,
#   'deadCount': 309,
#   'deadCountRank': 26,
#   'deadRate': '4.62',
#   'deadRateRank': 39,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 962001,
#   'countryShortCode': 'DNK',
#   'countryFullName': 'Denmark',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/831/3402160489185731552-135.json',
#   'incrVo': {'currentConfirmedIncr': -1854,
#    'confirmedIncr': 0,
#    'curedIncr': 1854,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552216,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '巴拿马',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3374,
#   'confirmedCount': 3472,
#   'confirmedCountRank': 44,
#   'suspectedCount': 0,
#   'curedCount': 4,
#   'deadCount': 94,
#   'deadCountRank': 45,
#   'deadRate': '2.70',
#   'deadRateRank': 69,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972007,
#   'countryShortCode': 'PAN',
#   'countryFullName': 'Panama',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/692/3402160525692954763-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552009,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '卡塔尔',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3298,
#   'confirmedCount': 3711,
#   'confirmedCountRank': 42,
#   'suspectedCount': 0,
#   'curedCount': 406,
#   'deadCount': 7,
#   'deadCountRank': 98,
#   'deadRate': '0.18',
#   'deadRateRank': 127,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955015,
#   'countryShortCode': 'QAT',
#   'countryFullName': 'Qatar',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/741/3402160510660391882-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551912,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '芬兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3155,
#   'confirmedCount': 3237,
#   'confirmedCountRank': 48,
#   'suspectedCount': 0,
#   'curedCount': 10,
#   'deadCount': 72,
#   'deadCountRank': 50,
#   'deadRate': '2.22',
#   'deadRateRank': 76,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 962002,
#   'countryShortCode': 'FIN',
#   'countryFullName': 'Finland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/473/3402160538577857276-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552016,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '多米尼加',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3103,
#   'confirmedCount': 3286,
#   'confirmedCountRank': 46,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 183,
#   'deadCountRank': 31,
#   'deadRate': '5.56',
#   'deadRateRank': 25,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974006,
#   'countryShortCode': 'DOM',
#   'countryFullName': 'Dominican Republic',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/651/3402160506365601251-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551968,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '白俄罗斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3079,
#   'confirmedCount': 3281,
#   'confirmedCountRank': 47,
#   'suspectedCount': 0,
#   'curedCount': 169,
#   'deadCount': 33,
#   'deadCountRank': 65,
#   'deadRate': '1.00',
#   'deadRateRank': 102,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964001,
#   'countryShortCode': 'BLR',
#   'countryFullName': 'Belarus',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/436/3402160510660391933-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552011,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '卢森堡',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3063,
#   'confirmedCount': 3373,
#   'confirmedCountRank': 45,
#   'suspectedCount': 0,
#   'curedCount': 241,
#   'deadCount': 69,
#   'deadCountRank': 51,
#   'deadRate': '2.04',
#   'deadRateRank': 83,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961004,
#   'countryShortCode': 'LUX',
#   'countryFullName': 'Luxembourg',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/943/3402160538577857289-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551897,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '3',
#   'provinceName': '新加坡',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3037,
#   'confirmedCount': 3699,
#   'confirmedCountRank': 43,
#   'suspectedCount': 0,
#   'curedCount': 652,
#   'deadCount': 10,
#   'deadCountRank': 88,
#   'deadRate': '0.27',
#   'deadRateRank': 123,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952009,
#   'countryShortCode': 'SGP',
#   'countryFullName': 'Singapore',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/901/3402160525692777969-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552163,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '哥伦比亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2889,
#   'confirmedCount': 3105,
#   'confirmedCountRank': 49,
#   'suspectedCount': 0,
#   'curedCount': 85,
#   'deadCount': 131,
#   'deadCountRank': 38,
#   'deadRate': '4.21',
#   'deadRateRank': 46,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973005,
#   'countryShortCode': 'COL',
#   'countryFullName': 'Colombia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/269/3402160512808052512-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551901,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '7',
#   'provinceName': '韩国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2750,
#   'confirmedCount': 10591,
#   'confirmedCountRank': 22,
#   'suspectedCount': 0,
#   'curedCount': 7616,
#   'deadCount': 225,
#   'deadCountRank': 29,
#   'deadRate': '2.12',
#   'deadRateRank': 80,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 951004,
#   'countryShortCode': 'KOR',
#   'countryFullName': 'Republic of Korea',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/779/3402160514955536234-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552160,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '南非',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2427,
#   'confirmedCount': 2506,
#   'confirmedCountRank': 52,
#   'suspectedCount': 0,
#   'curedCount': 45,
#   'deadCount': 34,
#   'deadCountRank': 64,
#   'deadRate': '1.35',
#   'deadRateRank': 95,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 984011,
#   'countryShortCode': 'ZAF',
#   'countryFullName': 'South Africa',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/417/3402160540725164203-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551898,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '4',
#   'provinceName': '马来西亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2343,
#   'confirmedCount': 5072,
#   'confirmedCountRank': 39,
#   'suspectedCount': 0,
#   'curedCount': 2647,
#   'deadCount': 82,
#   'deadCountRank': 47,
#   'deadRate': '1.61',
#   'deadRateRank': 91,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952007,
#   'countryShortCode': 'MYS',
#   'countryFullName': 'Malaysia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/777/3402160506365601260-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551956,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '希腊',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2071,
#   'confirmedCount': 2192,
#   'confirmedCountRank': 54,
#   'suspectedCount': 0,
#   'curedCount': 19,
#   'deadCount': 102,
#   'deadCountRank': 43,
#   'deadRate': '4.65',
#   'deadRateRank': 38,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965007,
#   'countryShortCode': 'GRC',
#   'countryFullName': 'Greece',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/800/3402160534282889817-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552061,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '阿根廷',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1991,
#   'confirmedCount': 2571,
#   'confirmedCountRank': 51,
#   'suspectedCount': 0,
#   'curedCount': 468,
#   'deadCount': 112,
#   'deadCountRank': 41,
#   'deadRate': '4.35',
#   'deadRateRank': 44,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973001,
#   'countryShortCode': 'ARG',
#   'countryFullName': 'Argentina',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/963/3402160508513085001-135.json',
#   'incrVo': {'currentConfirmedIncr': 121,
#    'confirmedIncr': 128,
#    'curedIncr': 0,
#    'deadIncr': 7},
#   'showRank': True},
#  {'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '999',
#   'provinceName': '中国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1910,
#   'confirmedCount': 83798,
#   'confirmedCountRank': 7,
#   'suspectedCount': 0,
#   'curedCount': 78536,
#   'deadCount': 3352,
#   'deadCountRank': 9,
#   'deadRate': '4.00',
#   'deadRateRank': 50,
#   'locationId': 951001,
#   'countryShortCode': 'CHN',
#   'countryFullName': 'China',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0416/269/3408054728356472057-135.json',
#   'incrVo': {'currentConfirmedIncr': -94,
#    'confirmedIncr': 53,
#    'curedIncr': 147,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552171,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '摩尔多瓦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1834,
#   'confirmedCount': 2049,
#   'confirmedCountRank': 56,
#   'suspectedCount': 0,
#   'curedCount': 171,
#   'deadCount': 44,
#   'deadCountRank': 58,
#   'deadRate': '2.14',
#   'deadRateRank': 79,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964005,
#   'countryShortCode': 'MDA',
#   'countryFullName': 'Republic of Moldova',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/234/3402160527840438516-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551930,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '埃及',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1769,
#   'confirmedCount': 2505,
#   'confirmedCountRank': 53,
#   'suspectedCount': 0,
#   'curedCount': 553,
#   'deadCount': 183,
#   'deadCountRank': 31,
#   'deadRate': '7.30',
#   'deadRateRank': 16,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981002,
#   'countryShortCode': 'EGY',
#   'countryFullName': 'Egypt',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/246/3402160540725341003-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552046,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '摩洛哥',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1668,
#   'confirmedCount': 2024,
#   'confirmedCountRank': 57,
#   'suspectedCount': 0,
#   'curedCount': 229,
#   'deadCount': 127,
#   'deadCountRank': 39,
#   'deadRate': '6.27',
#   'deadRateRank': 20,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981004,
#   'countryShortCode': 'MAR',
#   'countryFullName': 'Morocco',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/520/3402160510660391844-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552141,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '匈牙利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1311,
#   'confirmedCount': 1652,
#   'confirmedCountRank': 61,
#   'suspectedCount': 0,
#   'curedCount': 199,
#   'deadCount': 142,
#   'deadCountRank': 36,
#   'deadRate': '8.59',
#   'deadRateRank': 12,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963004,
#   'countryShortCode': 'HUN',
#   'countryFullName': 'Hungary',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/954/3402160538577857255-135.json',
#   'incrVo': {'currentConfirmedIncr': 58,
#    'confirmedIncr': 73,
#    'curedIncr': 7,
#    'deadIncr': 8},
#   'showRank': True},
#  {'id': 2551960,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '爱沙尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1248,
#   'confirmedCount': 1400,
#   'confirmedCountRank': 64,
#   'suspectedCount': 0,
#   'curedCount': 117,
#   'deadCount': 35,
#   'deadCountRank': 62,
#   'deadRate': '2.50',
#   'deadRateRank': 73,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964002,
#   'countryShortCode': 'EST',
#   'countryFullName': 'Estonia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/704/3402160514955359338-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551952,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '克罗地亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1235,
#   'confirmedCount': 1741,
#   'confirmedCountRank': 58,
#   'suspectedCount': 0,
#   'curedCount': 473,
#   'deadCount': 33,
#   'deadCountRank': 65,
#   'deadRate': '1.89',
#   'deadRateRank': 85,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965005,
#   'countryShortCode': 'HRV',
#   'countryFullName': 'Croatia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/154/3402160527840438555-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2551948,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '科威特',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1196,
#   'confirmedCount': 1405,
#   'confirmedCountRank': 63,
#   'suspectedCount': 0,
#   'curedCount': 206,
#   'deadCount': 3,
#   'deadCountRank': 115,
#   'deadRate': '0.21',
#   'deadRateRank': 126,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955011,
#   'countryShortCode': 'KWT',
#   'countryFullName': 'Kuwait',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/529/3402160514955359370-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552395,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '哈萨克斯坦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1125,
#   'confirmedCount': 1275,
#   'confirmedCountRank': 65,
#   'suspectedCount': 0,
#   'curedCount': 138,
#   'deadCount': 12,
#   'deadCountRank': 85,
#   'deadRate': '0.94',
#   'deadRateRank': 104,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 954001,
#   'countryShortCode': 'KAZ',
#   'countryFullName': 'Kazakhstan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0316/156/3402290551532568675-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 2552416,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
# ...
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552541,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '北马里亚纳群岛联邦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 9,
#   'confirmedCount': 11,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 2,
#   'deadRate': '18.18',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'CNMI',
#   'countryFullName': 'Northern Mariana Islands (Commonwealth of the)',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0330/319/3404907558858335978-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552517,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '特克斯和凯科斯群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 9,
#   'confirmedCount': 10,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 1,
#   'deadRate': '10.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'TCA',
#   'countryFullName': 'Turks & Caicos\xa0Islands',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0325/278/3403979839479981638-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552408,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '斯威士兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 8,
#   'confirmedCount': 16,
#   'suspectedCount': 0,
#   'curedCount': 8,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 984010,
#   'countryShortCode': 'SWZ',
#   'countryFullName': 'Swaziland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0316/269/3402290530057731261-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552460,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '尼加拉瓜',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 8,
#   'confirmedCount': 9,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 1,
#   'deadRate': '11.11',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972006,
#   'countryShortCode': 'NIC',
#   'countryFullName': 'Nicaragua',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/114/3403052105069099819-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552157,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '梵蒂冈',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 8,
#   'confirmedCount': 8,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965017,
#   'countryShortCode': 'VAT',
#   'countryFullName': 'Holy See',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/719/3402160489185554691-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552166,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '马尔代夫',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6,
#   'confirmedCount': 20,
#   'suspectedCount': 0,
#   'curedCount': 14,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953004,
#   'countryShortCode': 'MDV',
#   'countryFullName': 'Maldives',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/023/3402160529987922354-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552432,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '冈比亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6,
#   'confirmedCount': 9,
#   'suspectedCount': 0,
#   'curedCount': 2,
#   'deadCount': 1,
#   'deadRate': '11.11',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 982005,
#   'countryShortCode': 'GMB',
#   'countryFullName': 'Gambia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/124/3403052102921616068-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552427,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣巴泰勒米岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6,
#   'confirmedCount': 6,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'BL',
#   'countryFullName': 'Saint Barthelemy',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/743/3402535562237228754-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552495,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '东帝汶',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 6,
#   'confirmedCount': 6,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952004,
#   'countryShortCode': 'TLS',
#   'countryFullName': 'Tinor-Leste',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0322/192/3403423200980673679-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552400,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '苏里南',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5,
#   'confirmedCount': 10,
#   'suspectedCount': 0,
#   'curedCount': 4,
#   'deadCount': 1,
#   'deadRate': '10.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973010,
#   'countryShortCode': 'SUR',
#   'countryFullName': 'Suriname',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/931/3402535553647091547-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552156,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '不丹',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5,
#   'confirmedCount': 5,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953002,
#   'countryShortCode': 'BTN',
#   'countryFullName': 'Bhutan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/431/3402160508513085059-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552550,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '福克兰群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 5,
#   'confirmedCount': 5,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'FLK',
#   'countryFullName': 'Falkland Islands',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0406/989/3406206348378627968-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552407,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '毛里塔尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4,
#   'confirmedCount': 7,
#   'suspectedCount': 0,
#   'curedCount': 2,
#   'deadCount': 1,
#   'deadRate': '14.28',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 982012,
#   'countryShortCode': 'MRT',
#   'countryFullName': 'Mauritania',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0316/365/3402290519320312697-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552545,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '布隆迪共和国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4,
#   'confirmedCount': 5,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 1,
#   'deadRate': '20.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'BDI',
#   'countryFullName': 'The Republic of Burundi',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0401/018/3405278646179898791-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552548,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '荷兰加勒比地区',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4,
#   'confirmedCount': 4,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'BES',
#   'countryFullName': 'Bonaire, Sint Eustatius and Saba',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0405/351/3406020801496170129-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552549,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '南苏丹',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4,
#   'confirmedCount': 4,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981007,
#   'countryShortCode': 'SSD',
#   'countryFullName': 'South Sudan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0406/921/3406206348378627964-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552552,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '圣多美和普林西比',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4,
#   'confirmedCount': 4,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 983007,
#   'countryShortCode': 'STP',
#   'countryFullName': 'São Tomé and Príncipe',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0407/502/3406391893113208137-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552537,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '安圭拉',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3,
#   'confirmedCount': 3,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'AI',
#   'countryFullName': 'Anguilla',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0328/700/3404536465093591382-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552538,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '英属维尔京群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3,
#   'confirmedCount': 3,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'VG',
#   'countryFullName': 'VirginIslands,British',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0328/125/3404536465093935059-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552500,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '巴布亚新几内亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 2,
#   'confirmedCount': 2,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 990009,
#   'countryShortCode': 'PNG',
#   'countryFullName': 'Papua New Guinea',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0322/772/3403423200980799180-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552553,
#   'createTime': 1587029379000,
#   'modifyTime': 1587029379000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣皮埃尔和密克隆群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1,
#   'confirmedCount': 1,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'SPM',
#   'countryFullName': 'Saint Pierre and Miquelon',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0409/335/3406762986877325512-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 2552571,
#   'createTime': 1587029380000,
#   'modifyTime': 1587029380000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '也门共和国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1,
#   'confirmedCount': 1,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'YEM',
#   'countryFullName': 'The Republic of Yemen',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0411/999/3407134067757035603-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False}]

# %%
needed_data=[{
    'continents':country['continents'],
    'country_name':country['provinceName'],
    'current_confirmed_count':country['currentConfirmedCount'],
    'confirmed_count':country['confirmedCount'],
    'cured_count':country['curedCount'],
    'dead_count':country['deadCount'],
    'dead_rate':country['deadRate']
    }for country in data]
data=pd.DataFrame(needed_data)
data
# Out:
#     continents country_name  current_confirmed_count  confirmed_count  \
# 0          北美洲           美国                   555949           639628
# 1           欧洲          意大利                   105418           165155
# 2           欧洲          西班牙                    88201           177633
# 3           欧洲           英国                    85264            98476
# 4           亚洲          土耳其                    62200            69392
# ..         ...          ...                      ...              ...
# 207        北美洲          安圭拉                        3                3
# 208        北美洲      英属维尔京群岛                        3                3
# 209        大洋洲      巴布亚新几内亚                        2                2
# 210        北美洲   圣皮埃尔和密克隆群岛                        1                1
# 211         亚洲        也门共和国                        1                1
#
#      cured_count  dead_count dead_rate
# 0          52699       30980      4.84
# 1          38092       21645     13.10
# 2          70853       18579     10.45
# 3            344       12868     13.06
# 4           5674        1518      2.18
# ..           ...         ...       ...
# 207            0           0      0.00
# 208            0           0      0.00
# 209            0           0      0.00
# 210            0           0      0.00
# 211            0           0      0.00
#
# [212 rows x 7 columns]

# %%
data=data.sort_values(by='dead_count',ascending=False)
data
# Out:
#     continents country_name  current_confirmed_count  confirmed_count  \
# 0          北美洲           美国                   555949           639628
# 1           欧洲          意大利                   105418           165155
# 2           欧洲          西班牙                    88201           177633
# 5           欧洲           法国                    58039           106206
# 3           欧洲           英国                    85264            98476
# ..         ...          ...                      ...              ...
# 175        北美洲         圣卢西亚                       15               15
# 177        北美洲         格林那达                       14               14
# 178         非洲         纳米比亚                       13               16
# 180         非洲         塞拉利昂                       13               13
# 211         亚洲        也门共和国                        1                1
#
#      cured_count  dead_count dead_rate
# 0          52699       30980      4.84
# 1          38092       21645     13.10
# 2          70853       18579     10.45
# 5          31000       17167     16.16
# 3            344       12868     13.06
# ..           ...         ...       ...
# 175            0           0      0.00
# 177            0           0      0.00
# 178            3           0      0.00
# 180            0           0      0.00
# 211            0           0      0.00
#
# [212 rows x 7 columns]

# %%
grouped_data=data.groupby('continents')
data=grouped_data.sum()
data
# Out:
#             current_confirmed_count  confirmed_count  cured_count  dead_count
# continents
# 亚洲                           161937           333804       159757       12110
# 其他                              126              712          574          12
# 北美洲                          596443           684808        55474       32891
# 南美洲                           37094            59342        19518        2730
# 大洋洲                            6821             7789          889          79
# 欧洲                           577177           925122       260048       87897
# 非洲                            13856            17800         3030         914
