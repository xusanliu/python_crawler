# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers={'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}

# %%
def detail_url(url):
    result=[]
    html=requests.get(url,headers=headers)
    soup=BeautifulSoup(html.text,'lxml')
    title=soup.title.text
    result.append(title)
    academic=soup.select('.job_academic')[0].text
    result.append(academic)
    company_name=soup.select('.com_intro .com-name')[0].text
    company_name=company_name.replace('\n','')
    result.append(company_name)
    return result
def get_urls(url):
    a=[]
    b=[]
    c=[]
    html=requests.get(url,headers=headers)
    soup=BeautifulSoup(html.text,'lxml')
    offers=soup.select('.intern-wrap.intern-item')
    for offer in offers:
        url=offer.select('.f-l.intern-detail__job a')[0]['href']
        a.append(detail_url(url)[0])
        b.append(detail_url(url)[1])
        c.append(detail_url(url)[2])
    result={'title':a,
           'academic':b,
           'company_name':c}
    return result
url='https://www.shixiseng.com/interns?page=1&keyword=%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90%E5%AE%9E%E4%B9%A0%E7%94%9F'
print(get_urls(url))
# Out:
# {'title': ['数据分析实习生招聘_中国科学院网络实习生招聘 - 实习僧', '数据分析实习生招聘_微毕数据实习生招聘 - 实习僧', '数据分析实习生招聘_指南者留学实习生招聘 - 实习僧', '大数据分析师实习生招聘_科大讯飞实习生招聘 - 实习僧', '【21届】数据分析师/算法实习生招聘_网宿科技实习生招聘 - 实习僧', '数据分析师实习生招聘_K.P.Moritz实习生招聘 - 实习僧', '数据分析实习生招聘_指南者教育实习生招聘 - 实习僧', '数据分析实习生J13814实习生招聘_货拉拉实习生招聘 - 实习僧', '人力数据分析实习生招聘_融创中国实习生招聘 - 实习僧', '数据分析实习生招聘_璞元科技实习生招聘 - 实习僧', '数据分析实习生招聘_绝味食品实习生招聘 - 实习僧', '车险承保部数据分析实习生招聘_华农财险实习生招聘 - 实习僧', '数据分析实习生招聘_赛迪研究院实习生招聘 - 实习僧', '数据分析实习生招聘_利宝保险实习生招聘 - 实习僧', '数据分析实习生-市场部实习生招聘_捷信消费金融实习生招聘 - 实习僧', '数据分析实习生招聘_城市估价实习生招聘 - 实习僧', '数据分析实习生招聘_字节跳动实习生招聘 - 实习僧', '数据分析实习生招聘_众安保险实习生招聘 - 实习僧', '数据分析实习生 (MJ002873)实习生招聘_欢聚集团实习生招聘 - 实习僧', '数据分析实习生-网易严选实习生招聘_网易实习生招聘 - 实习僧'], 'academic': ['本科', '本科', '硕士', '本科', '本科', '硕士', '硕士', '本科', '本科', '本科', '硕士', '本科', '硕士', '本科', '本科', '本科', '本科', '本科', '本科', '本科'], 'company_name': ['中国科学院网络', '微毕数据', '指南者留学', '科大讯飞', '网宿科技', 'K.P.Moritz', '指南者教育', '货拉拉', '融创中国', '璞元科技', '绝味食品', '华农财险', '赛迪研究院', '利宝保险', '捷信消费金融', '城市估价', '字节跳动', '众安保险', '欢聚集团', '网易']}

# %%
data=pd.DataFrame(get_urls(url))
data
# Out:
#                                       title academic company_name
# 0              数据分析实习生招聘_中国科学院网络实习生招聘 - 实习僧       本科      中国科学院网络
# 1                 数据分析实习生招聘_微毕数据实习生招聘 - 实习僧       本科         微毕数据
# 2                数据分析实习生招聘_指南者留学实习生招聘 - 实习僧       硕士        指南者留学
# 3               大数据分析师实习生招聘_科大讯飞实习生招聘 - 实习僧       本科         科大讯飞
# 4        【21届】数据分析师/算法实习生招聘_网宿科技实习生招聘 - 实习僧       本科         网宿科技
# 5          数据分析师实习生招聘_K.P.Moritz实习生招聘 - 实习僧       硕士   K.P.Moritz
# 6                数据分析实习生招聘_指南者教育实习生招聘 - 实习僧       硕士        指南者教育
# 7         数据分析实习生J13814实习生招聘_货拉拉实习生招聘 - 实习僧       本科          货拉拉
# 8               人力数据分析实习生招聘_融创中国实习生招聘 - 实习僧       本科         融创中国
# 9                 数据分析实习生招聘_璞元科技实习生招聘 - 实习僧       本科         璞元科技
# 10                数据分析实习生招聘_绝味食品实习生招聘 - 实习僧       硕士         绝味食品
# 11           车险承保部数据分析实习生招聘_华农财险实习生招聘 - 实习僧       本科         华农财险
# 12               数据分析实习生招聘_赛迪研究院实习生招聘 - 实习僧       硕士        赛迪研究院
# 13                数据分析实习生招聘_利宝保险实习生招聘 - 实习僧       本科         利宝保险
# 14       数据分析实习生-市场部实习生招聘_捷信消费金融实习生招聘 - 实习僧       本科       捷信消费金融
# 15                数据分析实习生招聘_城市估价实习生招聘 - 实习僧       本科         城市估价
# 16                数据分析实习生招聘_字节跳动实习生招聘 - 实习僧       本科         字节跳动
# 17                数据分析实习生招聘_众安保险实习生招聘 - 实习僧       本科         众安保险
# 18  数据分析实习生 (MJ002873)实习生招聘_欢聚集团实习生招聘 - 实习僧       本科         欢聚集团
# 19          数据分析实习生-网易严选实习生招聘_网易实习生招聘 - 实习僧       本科           网易
